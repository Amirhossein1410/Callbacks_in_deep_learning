# %%
import os
os.chdir("/content/drive/MyDrive/Colab/Callback")

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import LambdaCallback

# %%
mnist = tf.keras.datasets.fashion_mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 1s 0us/step

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(
    x_train, y_train, epochs=10,
    callbacks=[LambdaCallback(on_epoch_begin=lambda epochs,logs: print(epochs))])
# Out:
# 0
# Epoch 1/10
# 1875/1875 [==============================] - 11s 3ms/step - loss: 0.4733 - accuracy: 0.8303
# 1
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3560 - accuracy: 0.8700
# 2
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3225 - accuracy: 0.8821
# 3
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2973 - accuracy: 0.8899
# 4
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2807 - accuracy: 0.8968
# 5
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2646 - accuracy: 0.9009
# 6
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2536 - accuracy: 0.9055
# 7
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2420 - accuracy: 0.9101
# 8
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2325 - accuracy: 0.9130
# 9
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2222 - accuracy: 0.9168
