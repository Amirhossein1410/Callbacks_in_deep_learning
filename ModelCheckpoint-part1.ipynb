# %%
import os
os.chdir("/content/drive/MyDrive/Colab/Callback")

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()
train_labels = train_labels[:1000]
test_labels = test_labels[:1000]
train_images = train_images[:1000].reshape(-1, 28 * 28) / 255.0
test_images = test_images[:1000].reshape(-1, 28 * 28) / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
# Define a simple sequential model
def create_model():
    model = tf.keras.models.Sequential([
        keras.layers.Dense(512, activation='relu', input_shape=(784,)),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(10, activation='softmax')
        ])
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
# Create a basic model instance
model = create_model()

# %%
checkpoint_path = "training_1/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)# Create a callback that saves the model's weights
cp_callback = ModelCheckpoint(filepath=checkpoint_path,
                                   save_weights_only=True,
                                   verbose=1)

# %%
# Train the model with the new callback
model.fit(train_images,
          train_labels,
          epochs=10,
          validation_data=(test_images,test_labels),
          callbacks=[cp_callback])  # Pass callback to training
# This may generate warnings related to saving the state of the optimizer.
# Out:
# Epoch 1/10
# 29/32 [==========================>...] - ETA: 0s - loss: 1.1853 - accuracy: 0.6487
# Epoch 1: saving model to training_1/cp.ckpt
# 32/32 [==============================] - 1s 12ms/step - loss: 1.1507 - accuracy: 0.6600 - val_loss: 0.7279 - val_accuracy: 0.7880
# Epoch 2/10
# 28/32 [=========================>....] - ETA: 0s - loss: 0.4019 - accuracy: 0.8839
# Epoch 2: saving model to training_1/cp.ckpt
# 32/32 [==============================] - 0s 8ms/step - loss: 0.4069 - accuracy: 0.8830 - val_loss: 0.5751 - val_accuracy: 0.8250
# Epoch 3/10
# 31/32 [============================>.] - ETA: 0s - loss: 0.2951 - accuracy: 0.9214
# Epoch 3: saving model to training_1/cp.ckpt
# 32/32 [==============================] - 0s 7ms/step - loss: 0.2954 - accuracy: 0.9220 - val_loss: 0.4602 - val_accuracy: 0.8510
# Epoch 4/10
# 17/32 [==============>...............] - ETA: 0s - loss: 0.1982 - accuracy: 0.9559
# Epoch 4: saving model to training_1/cp.ckpt
# 32/32 [==============================] - 0s 7ms/step - loss: 0.2141 - accuracy: 0.9430 - val_loss: 0.4475 - val_accuracy: 0.8580
# Epoch 5/10
# 32/32 [==============================] - ETA: 0s - loss: 0.1560 - accuracy: 0.9640
# Epoch 5: saving model to training_1/cp.ckpt
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1560 - accuracy: 0.9640 - val_loss: 0.4455 - val_accuracy: 0.8510
# Epoch 6/10
# 31/32 [============================>.] - ETA: 0s - loss: 0.1177 - accuracy: 0.9768
# Epoch 6: saving model to training_1/cp.ckpt
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1171 - accuracy: 0.9770 - val_loss: 0.4758 - val_accuracy: 0.8430
# Epoch 7/10
# 31/32 [============================>.] - ETA: 0s - loss: 0.0835 - accuracy: 0.9879
# Epoch 7: saving model to training_1/cp.ckpt
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0842 - accuracy: 0.9880 - val_loss: 0.4610 - val_accuracy: 0.8530
# Epoch 8/10
# 16/32 [==============>...............] - ETA: 0s - loss: 0.0616 - accuracy: 0.9961
# Epoch 8: saving model to training_1/cp.ckpt
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0629 - accuracy: 0.9940 - val_loss: 0.4230 - val_accuracy: 0.8620
# Epoch 9/10
# 16/32 [==============>...............] - ETA: 0s - loss: 0.0531 - accuracy: 0.9941
# Epoch 9: saving model to training_1/cp.ckpt
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0528 - accuracy: 0.9940 - val_loss: 0.4497 - val_accuracy: 0.8550
# Epoch 10/10
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0367 - accuracy: 0.9990
# Epoch 10: saving model to training_1/cp.ckpt
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0380 - accuracy: 0.9990 - val_loss: 0.4384 - val_accuracy: 0.8700

# %%
# Create a basic model instance
model = create_model()# Evaluate the model
loss, acc = model.evaluate(test_images, test_labels, verbose=0)
print("Untrained model, accuracy: {:5.2f}%".format(100*acc))
# Out:
# Untrained model, accuracy: 13.00%

# %%
# Loads the weights
model.load_weights(checkpoint_path)# Re-evaluate the model
loss,acc = model.evaluate(test_images, test_labels, verbose=0)
print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# Out:
# Restored model, accuracy: 87.00%
