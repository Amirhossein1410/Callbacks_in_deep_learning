# %%
import os
os.chdir("/content/drive/MyDrive/Colab/Callback")

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()
train_labels = train_labels[:1000]
test_labels = test_labels[:1000]
train_images = train_images[:1000].reshape(-1, 28 * 28) / 255.0
test_images = test_images[:1000].reshape(-1, 28 * 28) / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
# Define a simple sequential model
def create_model():
    model = tf.keras.models.Sequential([
        keras.layers.Dense(512, activation='relu', input_shape=(784,)),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(10, activation='softmax')
        ])
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
# Create a basic model instance
model = create_model()

# %% [markdown]
# ## Define checkpoint path and checkpoint directory

# %%
# Include the epoch in the file name (uses `str.format`)
checkpoint_path = "training_2/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)#previoulsy, checkpoint_path = "training_1/cp.ckpt"

# %% [markdown]
# ### Create a callback that saves model’s weights

# %%
# Create a callback that saves the model's weights every 5 epochs
cp_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=True,
    save_freq='epoch', period=5)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# # Create a new model and model fitting with a new callback (training)

# %%
# Create a new model instance
model = create_model()

# Save the weights using the `checkpoint_path` format
model.save_weights(checkpoint_path.format(epoch=0))

# Train the model with the new callback
model.fit(train_images,
          train_labels,
          epochs=50,
          callbacks=[cp_callback],
          validation_data=(test_images,test_labels),
          verbose=2)
# Out:
# Epoch 1/50
# 32/32 - 8s - loss: 1.1868 - accuracy: 0.6550 - val_loss: 0.7548 - val_accuracy: 0.7790 - 8s/epoch - 250ms/step
# Epoch 2/50
# 32/32 - 0s - loss: 0.4360 - accuracy: 0.8800 - val_loss: 0.5699 - val_accuracy: 0.8230 - 153ms/epoch - 5ms/step
# Epoch 3/50
# 32/32 - 0s - loss: 0.2801 - accuracy: 0.9310 - val_loss: 0.4859 - val_accuracy: 0.8470 - 160ms/epoch - 5ms/step
# Epoch 4/50
# 32/32 - 0s - loss: 0.2090 - accuracy: 0.9500 - val_loss: 0.4442 - val_accuracy: 0.8660 - 157ms/epoch - 5ms/step
# Epoch 5/50
#
# Epoch 5: saving model to training_2/cp-0005.ckpt
# 32/32 - 0s - loss: 0.1583 - accuracy: 0.9670 - val_loss: 0.4260 - val_accuracy: 0.8680 - 265ms/epoch - 8ms/step
# Epoch 6/50
# 32/32 - 0s - loss: 0.1198 - accuracy: 0.9760 - val_loss: 0.4092 - val_accuracy: 0.8640 - 157ms/epoch - 5ms/step
# Epoch 7/50
# 32/32 - 0s - loss: 0.0899 - accuracy: 0.9860 - val_loss: 0.4202 - val_accuracy: 0.8740 - 152ms/epoch - 5ms/step
# Epoch 8/50
# 32/32 - 0s - loss: 0.0706 - accuracy: 0.9910 - val_loss: 0.4034 - val_accuracy: 0.8690 - 156ms/epoch - 5ms/step
# Epoch 9/50
# 32/32 - 0s - loss: 0.0483 - accuracy: 0.9960 - val_loss: 0.4000 - val_accuracy: 0.8720 - 160ms/epoch - 5ms/step
# Epoch 10/50
#
# Epoch 10: saving model to training_2/cp-0010.ckpt
# 32/32 - 0s - loss: 0.0375 - accuracy: 0.9980 - val_loss: 0.4182 - val_accuracy: 0.8640 - 220ms/epoch - 7ms/step
# Epoch 11/50
# 32/32 - 0s - loss: 0.0319 - accuracy: 0.9970 - val_loss: 0.4048 - val_accuracy: 0.8750 - 181ms/epoch - 6ms/step
# Epoch 12/50
# 32/32 - 0s - loss: 0.0267 - accuracy: 1.0000 - val_loss: 0.4086 - val_accuracy: 0.8760 - 160ms/epoch - 5ms/step
# Epoch 13/50
# 32/32 - 0s - loss: 0.0231 - accuracy: 0.9990 - val_loss: 0.4179 - val_accuracy: 0.8730 - 158ms/epoch - 5ms/step
# Epoch 14/50
# 32/32 - 0s - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.4006 - val_accuracy: 0.8770 - 153ms/epoch - 5ms/step
# Epoch 15/50
#
# Epoch 15: saving model to training_2/cp-0015.ckpt
# 32/32 - 0s - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.4140 - val_accuracy: 0.8760 - 212ms/epoch - 7ms/step
# Epoch 16/50
# 32/32 - 0s - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.4219 - val_accuracy: 0.8730 - 153ms/epoch - 5ms/step
# Epoch 17/50
# 32/32 - 0s - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.4115 - val_accuracy: 0.8760 - 162ms/epoch - 5ms/step
# Epoch 18/50
# 32/32 - 0s - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.4221 - val_accuracy: 0.8760 - 163ms/epoch - 5ms/step
# Epoch 19/50
# 32/32 - 0s - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.4198 - val_accuracy: 0.8770 - 156ms/epoch - 5ms/step
# Epoch 20/50
#
# Epoch 20: saving model to training_2/cp-0020.ckpt
# 32/32 - 0s - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.4248 - val_accuracy: 0.8790 - 245ms/epoch - 8ms/step
# Epoch 21/50
# 32/32 - 0s - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.4223 - val_accuracy: 0.8780 - 160ms/epoch - 5ms/step
# Epoch 22/50
# 32/32 - 0s - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.4275 - val_accuracy: 0.8800 - 155ms/epoch - 5ms/step
# Epoch 23/50
# 32/32 - 0s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.4369 - val_accuracy: 0.8750 - 162ms/epoch - 5ms/step
# Epoch 24/50
# 32/32 - 0s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.4374 - val_accuracy: 0.8790 - 156ms/epoch - 5ms/step
# Epoch 25/50
#
# Epoch 25: saving model to training_2/cp-0025.ckpt
# 32/32 - 0s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.4355 - val_accuracy: 0.8830 - 222ms/epoch - 7ms/step
# Epoch 26/50
# 32/32 - 0s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.4474 - val_accuracy: 0.8750 - 164ms/epoch - 5ms/step
# Epoch 27/50
# 32/32 - 0s - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.4415 - val_accuracy: 0.8800 - 161ms/epoch - 5ms/step
# Epoch 28/50
# 32/32 - 0s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4456 - val_accuracy: 0.8770 - 238ms/epoch - 7ms/step
# Epoch 29/50
# 32/32 - 0s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4543 - val_accuracy: 0.8760 - 235ms/epoch - 7ms/step
# Epoch 30/50
#
# Epoch 30: saving model to training_2/cp-0030.ckpt
# 32/32 - 0s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4523 - val_accuracy: 0.8790 - 225ms/epoch - 7ms/step
# Epoch 31/50
# 32/32 - 0s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.4513 - val_accuracy: 0.8820 - 238ms/epoch - 7ms/step
# Epoch 32/50
# 32/32 - 0s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.4489 - val_accuracy: 0.8820 - 168ms/epoch - 5ms/step
# Epoch 33/50
# 32/32 - 0s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.4592 - val_accuracy: 0.8800 - 161ms/epoch - 5ms/step
# Epoch 34/50
# 32/32 - 0s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.4586 - val_accuracy: 0.8780 - 156ms/epoch - 5ms/step
# Epoch 35/50
#
# Epoch 35: saving model to training_2/cp-0035.ckpt
# 32/32 - 0s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.4582 - val_accuracy: 0.8830 - 221ms/epoch - 7ms/step
# Epoch 36/50
# 32/32 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4634 - val_accuracy: 0.8790 - 164ms/epoch - 5ms/step
# Epoch 37/50
# 32/32 - 0s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.4675 - val_accuracy: 0.8810 - 161ms/epoch - 5ms/step
# Epoch 38/50
# 32/32 - 0s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.4635 - val_accuracy: 0.8780 - 159ms/epoch - 5ms/step
# Epoch 39/50
# 32/32 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4669 - val_accuracy: 0.8820 - 164ms/epoch - 5ms/step
# Epoch 40/50
#
# Epoch 40: saving model to training_2/cp-0040.ckpt
# 32/32 - 0s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4687 - val_accuracy: 0.8830 - 236ms/epoch - 7ms/step
# Epoch 41/50
# 32/32 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4689 - val_accuracy: 0.8790 - 157ms/epoch - 5ms/step
# Epoch 42/50
# 32/32 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4709 - val_accuracy: 0.8820 - 153ms/epoch - 5ms/step
# Epoch 43/50
# 32/32 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.4738 - val_accuracy: 0.8820 - 156ms/epoch - 5ms/step
# Epoch 44/50
# 32/32 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4758 - val_accuracy: 0.8790 - 243ms/epoch - 8ms/step
# Epoch 45/50
#
# Epoch 45: saving model to training_2/cp-0045.ckpt
# 32/32 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.4689 - val_accuracy: 0.8820 - 242ms/epoch - 8ms/step
# Epoch 46/50
# 32/32 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4806 - val_accuracy: 0.8770 - 161ms/epoch - 5ms/step
# Epoch 47/50
# 32/32 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4833 - val_accuracy: 0.8820 - 160ms/epoch - 5ms/step
# Epoch 48/50
# 32/32 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4820 - val_accuracy: 0.8800 - 156ms/epoch - 5ms/step
# Epoch 49/50
# 32/32 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4813 - val_accuracy: 0.8790 - 192ms/epoch - 6ms/step
# Epoch 50/50
#
# Epoch 50: saving model to training_2/cp-0050.ckpt
# 32/32 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4843 - val_accuracy: 0.8800 - 352ms/epoch - 11ms/step

# %% [markdown]
# Then, we want to look at the list of resulting checkpoints and then check the lastest checkpoint and name it ‘latest’

# %%
latest = tf.train.latest_checkpoint(checkpoint_dir)
latest
# Out:
# 'training_2/cp-0050.ckpt'

# %% [markdown]
# # Recreate a model and reload the latest checkpoint

# %%
# Create a new model instance
model = create_model()

# Load the previously saved weights
model.load_weights(latest)

# Re-evaluate the model
loss, acc = model.evaluate(test_images, test_labels, verbose=0)
print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# Out:
# Restored model, accuracy: 88.00%
