# %%
import os
os.chdir("/content/drive/MyDrive/Colab/Callback")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import TensorBoard
import os
import datetime

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
def create_model():
    return tf.keras.models.Sequential([
        tf.keras.layers.Flatten(input_shape=(28, 28)),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(10, activation='softmax')
    ])

# %%
model = create_model()
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
logDir = ".\\logs\\mlp256\\" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
print("logDir: ", logDir)
tensorboard_callback = TensorBoard(logDir, update_freq = 'batch', histogram_freq=1)

model.fit(x=x_train,
          y=y_train,
          epochs=5,
          validation_data=(x_test, y_test),
          callbacks=[tensorboard_callback])
# Out:
# logDir:  .\logs\mlp256\20231104-074441
# Epoch 1/5
# 1875/1875 [==============================] - 19s 9ms/step - loss: 0.2485 - accuracy: 0.9291 - val_loss: 0.1125 - val_accuracy: 0.9658
# Epoch 2/5
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.1127 - accuracy: 0.9661 - val_loss: 0.0829 - val_accuracy: 0.9745
# Epoch 3/5
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.0809 - accuracy: 0.9755 - val_loss: 0.0638 - val_accuracy: 0.9807
# Epoch 4/5
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.0644 - accuracy: 0.9797 - val_loss: 0.0653 - val_accuracy: 0.9810
# Epoch 5/5
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0532 - accuracy: 0.9828 - val_loss: 0.0725 - val_accuracy: 0.9792
