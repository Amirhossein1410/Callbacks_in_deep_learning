# %%
import os
os.chdir("/content/drive/MyDrive/Colab/Callback")

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import LearningRateScheduler
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mnist = tf.keras.datasets.fashion_mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
def scheduler(epoch):
    if epoch < 2:
        return 0.001
    elif epoch < 6:
        return 0.0001
    else:
        return 0.00001

learning_rate_scheduler = LearningRateScheduler(scheduler, verbose=1)

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=10, callbacks=[learning_rate_scheduler])
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.001.
# Epoch 1/10
# 1875/1875 [==============================] - 10s 3ms/step - loss: 0.4760 - accuracy: 0.8310 - lr: 0.0010
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.001.
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3571 - accuracy: 0.8690 - lr: 0.0010
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2824 - accuracy: 0.8963 - lr: 1.0000e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2707 - accuracy: 0.9004 - lr: 1.0000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2626 - accuracy: 0.9037 - lr: 1.0000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2559 - accuracy: 0.9056 - lr: 1.0000e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 1e-05.
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2450 - accuracy: 0.9101 - lr: 1.0000e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 1e-05.
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2430 - accuracy: 0.9110 - lr: 1.0000e-05
#
# Epoch 9: LearningRateScheduler setting learning rate to 1e-05.
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2420 - accuracy: 0.9114 - lr: 1.0000e-05
#
# Epoch 10: LearningRateScheduler setting learning rate to 1e-05.
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2412 - accuracy: 0.9119 - lr: 1.0000e-05
